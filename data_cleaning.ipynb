# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("G:/Mohanraj D_OFFICIAL/GUVI (Data Analyst)/Mini-Projects/EMI_Prediction/emi_prediction_dataset.csv")
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7952\929178912.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("G:/Mohanraj D_OFFICIAL/GUVI (Data Analyst)/Mini-Projects/EMI_Prediction/emi_prediction_dataset.csv")

# %%
df.head()
# Out:
#     age  gender marital_status     education monthly_salary employment_type  \
# 0  38.0  Female        Married  Professional        82600.0         Private
# 1  38.0  Female        Married      Graduate        21500.0         Private
# 2  38.0    Male        Married  Professional        86100.0         Private
# 3  58.0  Female        Married   High School        66800.0         Private
# 4  48.0  Female        Married  Professional        57300.0         Private
#
#    years_of_employment company_type house_type  monthly_rent  ...  \
# 0                  0.9     Mid-size     Rented       20000.0  ...
# 1                  7.0          MNC     Family           0.0  ...
# 2                  5.8      Startup        Own           0.0  ...
# 3                  2.2     Mid-size        Own           0.0  ...
# 4                  3.4     Mid-size     Family           0.0  ...
#
#    existing_loans  current_emi_amount  credit_score  bank_balance  \
# ...

# %%
df.dtypes
# Out:
# age                        object
# gender                     object
# marital_status             object
# education                  object
# monthly_salary             object
# employment_type            object
# years_of_employment       float64
# company_type               object
# house_type                 object
# monthly_rent              float64
# family_size                 int64
# dependents                  int64
# school_fees               float64
# college_fees              float64
# travel_expenses           float64
# groceries_utilities       float64
# other_monthly_expenses    float64
# existing_loans             object
# current_emi_amount        float64
# credit_score              float64
# bank_balance               object
# emergency_fund            float64
# emi_scenario               object
# requested_amount          float64
# requested_tenure            int64
# emi_eligibility            object
# max_monthly_emi           float64
# dtype: object

# %%
df['age'].unique()[:200]
# Out:
# array([38.0, 58.0, 48.0, 32.0, 27.0, 47.0, 37.0, 31.0, 59.0, 49.0, 33.0,
#        26.0, 39.0, 57.0, 28.0, '58', '38', '48', '32', '27', '37', '48.0',
#        '33', '38.0', '49', '27.0', '31', '39', '47', '59', '32.0', '58.0',
#        '57', '26', '28', '58.0.0', '39.0', '26.0', '37.0', '38.0.0',
#        '32.0.0'], dtype=object)

# %%
df['age'] = df['age'].astype(str).str.extract(r'(\d+)').astype(int)

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
df.isna().sum()
# Out:
# age                          0
# gender                       0
# marital_status               0
# education                 2404
# monthly_salary               0
# employment_type              0
# years_of_employment          0
# company_type                 0
# house_type                   0
# monthly_rent              2426
# family_size                  0
# dependents                   0
# school_fees                  0
# college_fees                 0
# travel_expenses              0
# groceries_utilities          0
# other_monthly_expenses       0
# existing_loans               0
# current_emi_amount           0
# credit_score              2420
# bank_balance              2426
# emergency_fund            2351
# emi_scenario                 0
# requested_amount             0
# requested_tenure             0
# emi_eligibility              0
# max_monthly_emi              0
# dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'female', 'male', 'M', 'MALE', 'F', 'FEMALE'],
#       dtype=object)

# %%
gender_map = {'Female': 'F',
             'female' : 'F',
              'F' :'F',
              'FEMALE' : 'F',
               'MALE' : 'M',
                 'Male' : 'M',
                  'male' : 'M',
                   'M' : 'M' 
            }

# %%
df['gender'] = df['gender'].astype(str).replace(gender_map)

# %%
df['gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['marital_status'].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
df['education'].unique()
# Out:
# array(['Professional', 'Graduate', 'High School', 'Post Graduate', nan],
#       dtype=object)

# %%
df['education'].isna().sum()
# Out:
# np.int64(2404)

# %%
df.shape
# Out:
# (404800, 27)

# %%
((df['education'].isna().sum()) / df.shape[0]) * 100
# Out:
# np.float64(0.5938735177865613)

# %%
df = df.dropna(subset=['education'])

# %%
df.shape
# Out:
# (402396, 27)

# %%
df.isna().sum()
# Out:
# age                          0
# gender                       0
# marital_status               0
# education                    0
# monthly_salary               0
# employment_type              0
# years_of_employment          0
# company_type                 0
# house_type                   0
# monthly_rent              2417
# family_size                  0
# dependents                   0
# school_fees                  0
# college_fees                 0
# travel_expenses              0
# groceries_utilities          0
# other_monthly_expenses       0
# existing_loans               0
# current_emi_amount           0
# credit_score              2405
# bank_balance              2411
# emergency_fund            2330
# emi_scenario                 0
# requested_amount             0
# requested_tenure             0
# emi_eligibility              0
# max_monthly_emi              0
# dtype: int64

# %%
df['monthly_salary'].unique()
# Out:
# array(['82600.0', '21500.0', '86100.0', ..., '56779.0', '56280.0',
#        '55905.0'], shape=(13601,), dtype=object)

# %%
df['monthly_salary'] = df['monthly_salary'].astype(str).str.extract(r'(\d+)').astype(int)

# %%
df['monthly_salary'].unique()
# Out:
# array([82600, 21500, 86100, ..., 56779, 56280, 55905], shape=(12762,))

# %%
df['monthly_salary'].dtype
# Out:
# dtype('int64')

# %%
df['employment_type'].unique()
# Out:
# array(['Private', 'Government', 'Self-employed'], dtype=object)

# %%
df['employment_type'].isna().sum()
# Out:
# np.int64(0)

# %%
df['years_of_employment'].unique()[:30]
# Out:
# array([ 0.9,  7. ,  5.8,  2.2,  3.4,  5. , 36. , 12.9,  1.9,  7.5,  3.7,
#         1.3,  3.2,  0.5, 26. ,  0.8,  4.2,  2.6,  3.9,  9.7,  4.7,  9.6,
#         1.7,  9.4,  4.1,  1. ,  7.6, 16. ,  2.5,  1.6])

# %%
df['years_of_employment'].isna().sum()
# Out:
# np.int64(0)

# %%
df['company_type'].dtype
# Out:
# dtype('O')

# %%
df['company_type'].isna().sum()
# Out:
# np.int64(0)

# %%
df['company_type'].unique()
# Out:
# array(['Mid-size', 'MNC', 'Startup', 'Large Indian', 'Small'],
#       dtype=object)

# %%
df['house_type'].unique()
# Out:
# array(['Rented', 'Family', 'Own'], dtype=object)

# %%
df['house_type'].isna().sum()
# Out:
# np.int64(0)

# %%
df['monthly_rent'].unique()[:40]
# Out:
# array([20000.,     0., 13500., 13100., 11700., 17600.,  8400., 16400.,
#         3800.,  7200., 14400.,  6700., 28300., 10900., 18300., 16900.,
#        18000., 10200.,  9500., 29500., 16224., 27800.,  5700., 11500.,
#        13900.,  9600., 11300., 16500., 13700., 13000., 12700., 12800.,
#        24900., 36500., 18200., 21800., 10400., 18500., 17900., 11900.])

# %%
df['monthly_rent'].isna().sum()
# Out:
# np.int64(2417)

# %%
df['monthly_rent'].dtype
# Out:
# dtype('float64')

# %%
df = df.dropna(subset=['monthly_rent'])

# %%
df['monthly_rent'].isna().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (399979, 27)

# %%
df['family_size'].isna().sum()
# Out:
# np.int64(0)

# %%
df['family_size'].unique()
# Out:
# array([3, 2, 4, 5, 1])

# %%
df['dependents'].unique()
# Out:
# array([2, 1, 3, 4, 0])

# %%
df['school_fees'].unique()
# Out:
# array([    0.,  5100., 11400.,  9400., 10200., 15000.,  8100., 10900.,
#        12000.,  9100., 10800.,  9300., 11700.,  5500.,  5400.,  8000.,
#         2400., 14400.,  3000., 12900.,  8300., 10600., 12300., 13800.,
#         9900., 12500.,  5900.,  3900.,  8500., 12700.,  6800.,  7900.,
#        11000.,  7700., 14100., 14300., 11200.,  4700., 11600.,  6500.,
#         6200., 10300.,  9800.,  5700.,  5200.,  2500.,  2000., 14500.,
#         9500.,  5000.,  8800., 11800.,  5300.,  2700.,  9600.,  7300.,
#         8200., 11300.,  4200.,  2200.,  3400.,  2100., 14700., 13500.,
#         8600., 10500.,  4400.,  3200., 10700.,  9000.,  5600.,  3500.,
#         7600., 13100.,  6600., 12800., 11100.,  3600., 13900.,  4500.,
#         7500.,  7400.,  2900., 11900.,  4100.,  8700.,  3800., 14000.,
#        12100.,  5800., 10000.,  7100., 10100.,  3700.,  7000., 14900.,
#         3300.,  4300.,  4600., 14200.,  6300.,  2300.,  6100., 13000.,
# ...

# %%
df['school_fees'].isna().sum()
# Out:
# np.int64(0)

# %%
df['school_fees'].dtype
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#    age gender marital_status     education  monthly_salary employment_type  \
# 0   38      F        Married  Professional           82600         Private
# 1   38      F        Married      Graduate           21500         Private
# 2   38      M        Married  Professional           86100         Private
# 3   58      F        Married   High School           66800         Private
# 4   48      F        Married  Professional           57300         Private
#
#    years_of_employment company_type house_type  monthly_rent  ...  \
# 0                  0.9     Mid-size     Rented       20000.0  ...
# 1                  7.0          MNC     Family           0.0  ...
# 2                  5.8      Startup        Own           0.0  ...
# 3                  2.2     Mid-size        Own           0.0  ...
# 4                  3.4     Mid-size     Family           0.0  ...
#
#    existing_loans  current_emi_amount  credit_score  bank_balance  \
# ...

# %%
df['college_fees'].isna().sum()
# Out:
# np.int64(0)

# %%
df['travel_expenses'].isna().sum()
# Out:
# np.int64(0)

# %%
df['groceries_utilities'].isna().sum()
# Out:
# np.int64(0)

# %%
df['other_monthly_expenses'].isna().sum()
# Out:
# np.int64(0)

# %%
df['existing_loans'].isna().sum()
# Out:
# np.int64(0)

# %%
df['existing_loans'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['current_emi_amount'].isna().sum()
# Out:
# np.int64(0)

# %%
df['credit_score'].isna().sum()
# Out:
# np.int64(2389)

# %%
df['credit_score'].unique()
# Out:
# array([ 660.,  714.,  650.,  685.,  770.,  792.,  741.,  623.,  712.,
#         681.,  791.,  560.,  695.,  691.,  788.,  664.,  662.,  665.,
#         655.,  719.,  663.,  765.,  804.,  755.,  808.,  710.,  769.,
#         648.,  746.,  614.,  819.,  570.,  606.,  717.,  546.,  702.,
#         718.,  694.,  729.,  732.,  705.,  850.,  697.,  737.,  670.,
#         700.,  727.,  628.,  731.,  730.,  745.,  798.,  668.,  653.,
#         735.,  630.,  704.,  686.,  716.,  678.,  578.,  762.,  693.,
#         756.,  703.,  799.,  543.,  690.,  639.,  669.,  608.,  728.,
#         676.,  777.,  636.,  840.,  616.,  849.,  688.,  722.,  725.,
#         617.,  739.,  637.,  706.,  846.,  818.,  654.,  698.,  631.,
#         753.,  790.,  713.,  738.,  696.,  821.,  626.,  618.,  658.,
#         841.,  679.,  794.,  646.,  780.,  640.,  721.,  692.,  673.,
#         656.,  843.,  715.,  701.,  754.,  805.,  595.,  576.,  747.,
# ...

# %%
df = df.dropna(subset=['credit_score'])

# %%
df['credit_score'].isna().sum()
# Out:
# np.int64(0)

# %%
df['emergency_fund'].isna().sum()
# Out:
# np.int64(2300)

# %%
df['bank_balance'] = pd.to_numeric(df['bank_balance'], errors='coerce')

# %%
df = df.dropna(subset=['bank_balance','emergency_fund'])

# %%
df.shape
# Out:
# (391003, 27)

# %%
df['emi_scenario'].unique()
# Out:
# array(['Personal Loan EMI', 'E-commerce Shopping EMI', 'Education EMI',
#        'Vehicle EMI', 'Home Appliances EMI'], dtype=object)

# %%
df['requested_tenure'].dtype
# Out:
# dtype('int64')

# %%
df['emi_eligibility'].isna().sum()
# Out:
# np.int64(0)

# %%
df['max_monthly_emi'].isna().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                  age  monthly_salary  years_of_employment   monthly_rent  \
# count  391003.000000   391003.000000        391003.000000  391003.000000
# mean       38.877239    59497.469055             5.368918    5825.720064
# std         9.300143    43359.602974             6.083775    8644.316643
# min        26.000000     3967.000000             0.500000       0.000000
# 25%        32.000000    35400.000000             1.200000       0.000000
# 50%        38.000000    51635.000000             3.200000       0.000000
# 75%        48.000000    73000.000000             7.200000   10600.000000
# max        59.000000   499970.000000            36.000000   80000.000000
#
#          family_size     dependents    school_fees   college_fees  \
# count  391003.000000  391003.000000  391003.000000  391003.000000
# mean        2.940553       1.940553    4626.056578    4067.813546
# std         1.075053       1.075053    5061.314027    7320.774393
# ...

# %%
df.to_csv("cleaned_emi_prediction_dataset.csv", index=False)

# %%
df_cleaned = pd.read_csv("cleaned_emi_prediction_dataset.csv")

# %%
df_cleaned.dtypes
# Out:
# age                         int64
# gender                     object
# marital_status             object
# education                  object
# monthly_salary              int64
# employment_type            object
# years_of_employment       float64
# company_type               object
# house_type                 object
# monthly_rent              float64
# family_size                 int64
# dependents                  int64
# school_fees               float64
# college_fees              float64
# travel_expenses           float64
# groceries_utilities       float64
# other_monthly_expenses    float64
# existing_loans             object
# current_emi_amount        float64
# credit_score              float64
# bank_balance              float64
# emergency_fund            float64
# emi_scenario               object
# requested_amount          float64
# requested_tenure            int64
# emi_eligibility            object
# max_monthly_emi           float64
# dtype: object
